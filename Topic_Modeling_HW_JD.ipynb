# %%
import requests
import pandas as pd
import spacy

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=d806445cbef0104eea4b477595d54bf6fbed8c5bc1ff888ceae74a8d3e068311
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
nlp = spacy.load("en_core_web_sm")
nlp.disable_pipes('ner', 'parser')
# Out:
# ['ner', 'parser']

# %%
# text is Walter Pater's "The Renaissance: Studies in Art and Poetry"
response = requests.get('https://www.gutenberg.org/cache/epub/2398/pg2398.txt')
text = response.text

# %%
text[:300]
# Out:
# '\ufeffThe Project Gutenberg eBook of The Renaissance: Studies in Art and Poetry\r\n    \r\nThis ebook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\no'

# %%
text.find('Many attempts have been made by writers on art and poetry to define')
# Out:
# 1127

# %%
text.find('*** END OF THE PROJECT GUTENBERG EBOOK THE RENAISSANCE: STUDIES IN ART AND POETRY ***')
# Out:
# 349683

# %%
start = 1127
end = 349683 -1

# %%
renaissance = text[start:end]

# %%
renaissance_paras = renaissance.split('\r\n\r\n')

# %%
author = []
title = []

# %%
for para in renaissance_paras:
    author.append('Walter Pater')
    title.append('The Renaissance: Studies in Art and Poetry')

# %%
renaissance_df = pd.DataFrame(list(zip(author, title, renaissance_paras)), columns=['author', 'title', 'text'])

# %%
renaissance_df.head()
# Out:
#          author                                       title  \
# 0  Walter Pater  The Renaissance: Studies in Art and Poetry
# 1  Walter Pater  The Renaissance: Studies in Art and Poetry
# 2  Walter Pater  The Renaissance: Studies in Art and Poetry
# 3  Walter Pater  The Renaissance: Studies in Art and Poetry
# 4  Walter Pater  The Renaissance: Studies in Art and Poetry
#
#                                                 text
# 0  Many attempts have been made by writers on art...
# 1  "To see the object as in itself it really is,"...
# 2  The aesthetic critic, then, regards all the ob...
# 3  What is important, then, is not that the criti...
# 4  Often it will require great nicety to disengag...

# %%
def process_text(text):
    """Remove new line characters and lemmatize text. Returns string of lemmas"""
    text = text.replace('\n', ' ')
    doc = nlp(text)
    tokens = [token for token in doc]
    no_stops = [token for token in tokens if not token.is_stop]
    no_punct = [token for token in no_stops if token.is_alpha]
    lemmas = [token.lemma_ for token in no_punct]
    lemmas_lower = [lemma.lower() for lemma in lemmas]
    lemmas_string = ' '.join(lemmas_lower)
    return lemmas_string

# %%
renaissance_df['lemmas'] = renaissance_df['text'].apply(process_text)

# %%
renaissance_df.head()
# Out:
#          author                                       title  \
# 0  Walter Pater  The Renaissance: Studies in Art and Poetry
# 1  Walter Pater  The Renaissance: Studies in Art and Poetry
# 2  Walter Pater  The Renaissance: Studies in Art and Poetry
# 3  Walter Pater  The Renaissance: Studies in Art and Poetry
# 4  Walter Pater  The Renaissance: Studies in Art and Poetry
#
#                                                 text  \
# 0  Many attempts have been made by writers on art...
# 1  "To see the object as in itself it really is,"...
# 2  The aesthetic critic, then, regards all the ob...
# 3  What is important, then, is not that the criti...
# 4  Often it will require great nicety to disengag...
#
#                                               lemmas
# 0  attempt writer art poetry define beauty abstra...
# 1  object justly say aim true criticism aesthetic...
# 2  aesthetic critic regard object work art fair f...
# 3  important critic possess correct abstract defi...
# 4  require great nicety disengage virtue commoner...

# %%
renaissance_df.to_csv('pater_dataframe.csv', index=False)

# %%
# !pip install pyLDAvis

# %%
from collections import defaultdict
import wget
from gensim import corpora, models
import pandas as pd
import pyLDAvis.gensim
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv('/content/pater_dataframe.csv')

# %%
df
# Out:
#            author                                       title  \
# 0    Walter Pater  The Renaissance: Studies in Art and Poetry
# 1    Walter Pater  The Renaissance: Studies in Art and Poetry
# 2    Walter Pater  The Renaissance: Studies in Art and Poetry
# 3    Walter Pater  The Renaissance: Studies in Art and Poetry
# 4    Walter Pater  The Renaissance: Studies in Art and Poetry
# ..            ...                                         ...
# 278  Walter Pater  The Renaissance: Studies in Art and Poetry
# 279  Walter Pater  The Renaissance: Studies in Art and Poetry
# 280  Walter Pater  The Renaissance: Studies in Art and Poetry
# 281  Walter Pater  The Renaissance: Studies in Art and Poetry
# 282  Walter Pater  The Renaissance: Studies in Art and Poetry
#
#                                                   text  \
# 0    Many attempts have been made by writers on art...
# 1    "To see the object as in itself it really is,"...
# 2    The aesthetic critic, then, regards all the ob...
# 3    What is important, then, is not that the criti...
# 4    Often it will require great nicety to disengag...
# ..                                                 ...
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                        \r\n        \r\n
#
#                                                 lemmas
# 0    attempt writer art poetry define beauty abstra...
# 1    object justly say aim true criticism aesthetic...
# 2    aesthetic critic regard object work art fair f...
# 3    important critic possess correct abstract defi...
# 4    require great nicety disengage virtue commoner...
# ..                                                 ...
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
#
# [283 rows x 4 columns]

# %%
documents = df['lemmas'].to_list()

# %%
#jd
#some of these are 'float' ...not sure why
floats= []
for d in documents:
  if type(d)== float:
    floats.append(d)

# %%
floats #it looks like you just have some null values in your dataframe
#This is just because some of the requests you made might not have any data associated with them
#so pandas added a Null (aka NaN) value
#when you try to then split the NaN value like you would a string, it throws an error
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
#thankfully pandas has super easy built in function to remove null values from your data frame!
#this is why data cleaning is so important but also annoyingly tedious at times- messy data can absolutely cause errors like this!

clean = df.dropna()
clean
# Out:
#            author                                       title  \
# 0    Walter Pater  The Renaissance: Studies in Art and Poetry
# 1    Walter Pater  The Renaissance: Studies in Art and Poetry
# 2    Walter Pater  The Renaissance: Studies in Art and Poetry
# 3    Walter Pater  The Renaissance: Studies in Art and Poetry
# 4    Walter Pater  The Renaissance: Studies in Art and Poetry
# ..            ...                                         ...
# 273  Walter Pater  The Renaissance: Studies in Art and Poetry
# 274  Walter Pater  The Renaissance: Studies in Art and Poetry
# 275  Walter Pater  The Renaissance: Studies in Art and Poetry
# 276  Walter Pater  The Renaissance: Studies in Art and Poetry
# 277  Walter Pater  The Renaissance: Studies in Art and Poetry
#
#                                                   text  \
# 0    Many attempts have been made by writers on art...
# 1    "To see the object as in itself it really is,"...
# 2    The aesthetic critic, then, regards all the ob...
# 3    What is important, then, is not that the criti...
# 4    Often it will require great nicety to disengag...
# ..                                                 ...
# 273  \r\nTo regard all things and principles of thi...
# 274  Or if we begin with the inward world of though...
# 275  Philosophiren, says Novalis, ist dephlegmatisi...
# 276  To burn always with this hard, gemlike flame, ...
# 277  One of the most beautiful passages in the writ...
#
#                                                 lemmas
# 0    attempt writer art poetry define beauty abstra...
# 1    object justly say aim true criticism aesthetic...
# 2    aesthetic critic regard object work art fair f...
# 3    important critic possess correct abstract defi...
# 4    require great nicety disengage virtue commoner...
# ..                                                 ...
# 273  regard thing principle thing inconstant mode f...
# 274  begin inward world thought feeling whirlpool r...
# 275  philosophiren say novalis ist dephlegmatisiren...
# 276  burn hard gemlike flame maintain ecstasy succe...
# 277  beautiful passage writing rousseau sixth book ...
#
# [258 rows x 4 columns]

# %%
clean.to_csv('pater_dataframe_clean.csv')

# %%
texts =[
    [word for word in document.lower().split()]
    for document in documents
]
